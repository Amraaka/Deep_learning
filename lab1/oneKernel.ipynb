# %% [markdown]
# # Шугаман давхрага
#
# Сэргээн санах CS308. Дараах шугаман давхрагын объектыг гүйцээн бичнэ үү.

# %%
import tensorflow as tf
import numpy as np

fac = 5
Mnist = tf.keras.datasets.mnist

class Linear_Layer:
    def __init__(self, in_dim, out_dim, alpha = 0.01, Theta = None, bias = None):
        self.alpha = alpha
        if Theta == None:
            self.Theta = np.random.randn(in_dim, out_dim)/fac
        else:
            self.Theta = Theta
        if bias == None:
            self.bias = np.random.randn(out_dim)/fac
        else:
            self.bias = bias
    def forward_pass(self, X):
        self.X = X
        # self.z = None
        self.z = np.matmul(X, self.Theta) + self.bias
        return self.z
    def backprop(self, grad_previous):
        t= self.X.shape[0]
        # self.grad = None
        self.grad = np.matmul(self.X.T, grad_previous) / t
        # self.grad_bias = None
        self.grad_bias = np.sum(grad_previous, axis=0) / t
        self.grad_a = np.matmul(grad_previous, self.Theta.transpose())
        return self.grad_a
    def applying_sgd(self):
            self.Theta = self.Theta - (self.alpha*self.grad)
            self.bias = self.bias - (self.alpha*self.grad_bias)
# Out:
# 2026-02-10 22:21:46.713686: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-10 22:21:46.748726: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-10 22:21:47.441143: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# # Convolution
#
# Convolutional Neural Networks нь өмнөх хичээлд үзсэн энгийн мэдрэлийн сүлжээнүүдтэй төстэй юм. Эдгээр нь суралцах боломжтой жин, биас бүхий нейронуудаас бүрддэг. Нейрон бүр зарим оролтыг хүлээн авч, цэгийн үржвэр хийж, дурын шугаман бус байдлаар ажилладаг. Сүлжээ нь нэг онооны функцийн уламжлалаар авсан алдаанаас суралцсаар байна. Оролтонд байгаа raw image pixels-ээс нөгөө гаралтанд байгаа ангийн оноо хүртэл урттай байна. Мөн сүүлийн (бүрэн холбогдсон) давхарга дээр (жишээ нь SVM/Softmax) гэх мэт алдагдал функцтэй байгаа бөгөөд тогтмол Neural Networks-ийг сурахад зориулан сүлжээний кодыг бичих нь энэхүү лабораторийн ажилын зорилго.
#
# Тэгвэл ямар өөрчлөлт гардаг вэ? ConvNet архитектурууд нь оролтууд нь зураг гэсэн тодорхой таамаглалыг гаргадаг бөгөөд энэ нь бидэнд тодорхой шинж чанаруудыг архитектурт кодлох боломжийг олгодог. Дараа нь эдгээр нь шууд чиглэлийн функцийг хэрэгжүүлэхэд илүү үр дүнтэй болгож, сүлжээн дэх параметрүүдийн хэмжээг маш ихээр багасгадаг. Тиймээг үүнийг онцлог шинжийг ялгагч гэж нэрлэх нь бас бий. Feature extractor.

# %% [markdown]
# CS308 Эргэн санахад: Мэдрэлийн сүлжээ Neural Network нь оролт (нэг вектор) хүлээн авч, хэд хэдэн нуугдмал давхаргуудаар дамжуулан хувиргадаг. Нуугдмал давхарга бүр нь нейронуудын багцаас бүтдэг. Өмнөх давхарга дахь нейрон бүр нь бүх нейронтой бүрэн холбогдсон байдаг үүнийг өөрөөр шугаман давхрага гэж нэрлэдэг. Мөн нэг давхарга дахь нейронууд бүрэн бие даасан байдлаар ажилладаг бөгөөд ямар нэгэн холболтыг хуваалцдаггүй. Хамгийн сүүлд бүрэн холбогдсон давхаргыг "өгөгдлийн давхарга", өөрөөр ангилагч гэж нэрлэдэг бөгөөд ангилалын нөхцөлд энэ нь ангийн оноог илэрхийлдэг.
#
# Тогтмол мэдрэлийн сүлжээ нь бүрэн дүрс том хэмжээний зураг боловсруулахад их хэмжээний параметр, тооцооллын хүндрэл гэх мэт учир дутагдалтай болохоор амьдралд сайн хэмждэггүй. CIFAR-10-т зураг нь зөвхөн 32х32х3 хэмжээтэй (32 өргөн, 32 өндөр, 3 өнгөт суваг) байдаг. Тиймээс мэдрэлийн сүлжээний эхний нуугдмал давхаргад ганц бүрэн холбогдсон нейрон нь 32\*32\*3 = 3072 оролт нь жинтэй байна. Энэ хэмжээг зохицуулах боломжтой мэт боловч бүрэн холбогдсон энэ сүлжээ нь илүү том дүрсүүдэд одоогын технологийн шийдэл боломжгүй болох нь тодорхой. Жишээ нь: илүү том хэмжээтэй зураг, 200x200x3, 200\*200\*3 = 120,000 жинтэй нейронууд руу хөтөлнө. Түүнээс гадна, бид хэд хэдэн ийм нейронтой давхрагатай болсоноор сайн загвар олж авах нь гарцаагүй. Тиймээс параметрүүд экспонциалаар нэмэгдэх болно!
#
# 3D хэмжээний нейронууд. Convolutional Neural Network-ийн оролт нь дүрсүүдээс бүрдэж, архитектурыг илүү ухаалаг аргаар хязгаарладаг гэдгээрээ давуу талтай. Ялангуяа тогтмол нейроны сүлжээнүүдийн ялгаатай нь ConvNet-ийн давхарга нь өргөн, өндөр, гүн гэсэн 3 хэмжээст нейронуудыг зохион байгуулсан байдаг. (Энд гүн гэдэг үг нь сүлжээнд нийт давхаргын тоог хэлж байна) Жишээ нь: CIFAR-10 дахь оролтын зураг нь идэвхижүүлэлтийн оролтын хэмжээ бөгөөд багтаамж нь 32х32х3 (өргөн, өндөр, гүн) хэмжээстэй байна. Бидний удахгүй харах болно. Давхарга дахь нейронууд нь бүх нейронуудыг бүрэн холбох маягаар биш харин түүнээс өмнө зөвхөн давхаргын жижиг хэсэгтэй холбогдоно. Түүнээс гадна, CIFAR-10-ийн эцсийн гаралтын давхарга нь 1x1x10 хэмжээтэй байх болно. Учир нь ConvNet архитектурын төгсгөлөөр бид бүрэн зургийг гүнзгий хэмжээсээр зохион байгуулсан нэг вектор болгон багасгах болно.
#
# ![Alt Text](https://cs231n.github.io/assets/nn1/neural_net2.jpeg)
#
# ![Alt Text](https://cs231n.github.io/assets/cnn/cnn.jpeg)

# %% [markdown]
# Бидний дээр өгүүлсэнчлэн энгийн ConvNet нь давхаргын дараалал бөгөөд ConvNet-ийн давхарга бүр нь ялгаатай функцээр дамжуулан нэг хэмжээний идэвхжүүлэлтийг нөгөөд хувиргадаг. Бид ConvNet архитектурыг бүтээхийн тулд үндсэн гурван төрлийн давхаргыг ашигладаг: Convolutional Layer, Pooling Layer, FC layer (CS308 Neural Network гэх мэт ангилагч давхрагууд). Бид эдгээр давхруудыг ашиглан ConvNet архитектурыг бий болгох болно.
#
# Загвар бүтээх арга барил: Бид доорх дэлгэрэнгүй мэдээллийг авч үзнэ, гэхдээ CIFAR-10 ангилалын энгийн ConvNet нь архитектуртай байж болно [INPUT - CONV - RELU - POOL - FC].
#
# Дэлгэрэнгүй:
# - INPUT [32x32x3] нь зургийн түүхий пикселийн утгийг авах бөгөөд энэ тохиолдолд өргөн 32, өндөр 32, гурван өнгөт сувагтай R,G,B гэсэн гурван өнгөний сувагтай дүрсийг өгнө.
#
# - CONV давхарга нь оролт дахь нейронуудын гаралтыг тооцоолно. Тус бүр нь тэдний жин болон оролтын хэмжээнд холбогдсон жижиг бүс нутгийн хооронд цэг үржвэр тооцоолно. Энэ нь 12 шүүлтүүр ашиглахаар шийдсэн бол [32x32x12] зэрэг хэмжээний гаралт гаргана.
#
# - RELU давхарга нь 0-д орох max(0,x) thresholding зэрэг элементийн идэвхижүүлэлтийн функцийг хэрэгжүүлнэ. Энэ нь тухайн оролтын хэмжээг өөрчлөхгүй орхидог ([32х32х12]).
#
# - POOL давхарга нь орон зайн хэмжээс (өргөн, өндөр) дагуу доошлуулах процессыг хэрэгжүүлнэ. Үүний үр дүнд [16x16x12] гэх мэт хэмжээстэй болно.
#
# - FC (өөрөөр хэлбэл бүрэн холбогдсон) давхарга нь хичээлийн оноог тооцоолно. Үүний үр дүнд хэмжээ нь [1x1x10] болно. Энд 10 тоо тус бүр нь CIFAR-10 гэсэн 10 ангилалын дунд зэрэг ангиллын оноотой дүйцэхүйц байна. Жирийн мэдрэлийн сүлжээнүүд болон нэрний утгад байгаа шиг энэ давхарга дахь нейрон бүр өмнөх боть дахь бүх тоонуудтай холбогдоно.

# %% [markdown]
# Ийнхүү ConvNets нь анхны зургийн давхаргыг анхны пикселийн утгаасс давхар өөрчилж, эцсийн ангийн оноог авдаг. Зарим давхаргын параметрүүд байдаг бол зарим нь байдаггүй. Ялангуяа, CONV/FC давхарга нь оролтын багтаамжийн идэвхжүүлэлтийн функц төдийгүй параметрүүдийн (нейронуудын жин, биас) функц болох хувирлуудыг гүйцэтгэдэг. Нөгөө талаас RELU/POOL давхарга нь тогтсон функцийг хэрэгжүүлнэ. CONV/FC давхарга дахь параметрүүдийг градиент доош нь сургах болно. Ингэснээр анги нь ConvNet-ийн тооцоолдог оноо нь дүрс бүрт зориулсан сургалтын багцын шошгуудтай нийцнэ.

# %% [markdown]
# 0-padding ашиглах. Зүүн талд байгаа дээрх жишээнд оролтын хэмжээ 5 байсан ба гаралтын хэмжээ нь тэнцүү байсныг анхаараарай: мөн 5. Энэ нь үр дүнгээ өгсөн. Учир нь бидний хүлээн авах талбай 3 байсан бөгөөд бид 1-ийн нөлөөг ашигласан юм. Хэрэв 0-пад хэрэглэхгүй байсан бол гаралтын хэмжээ нь ердөө 3-ын орон зайн хэмжээтэй байх байсан. Учир нь анхны оролтоор ийм олон нейрон "тохирох" байсан. Ерөнхийдөө 0 padding-ийг P=(F−1)/2 байхаар тохируулна. Энэ үед stride нь S=1 бөгөөд оролтын хэмжээ болон гаралтын хэмжээ нь ижил хэмжээтэй байх болно. Энэ аргаар 0-padding ашиглах нь маш түгээмэл байдаг.
#
# Алхам алхааг хязгаарлана. Орон зайн зохион байгуулалт гиперпараметрүүд харилцан хязгаарлалттай байдгийг дахин анхаараарай. Жишээлбэл оролт нь W=10 хэмжээтэй бол ямар ч zero-padding-ийг ашигладаггүй P=0, мөн шүүлтүүрийн хэмжээ нь F=3, тэгээд stride S=2-ыг ашиглах боломжгүй болно. Учир нь $$(W−F+2P)/S+1=(10−3+0)/2+1=4.5$$ , өөрөөр хэлбэл интеграцч биш юм. Энэ нь нейронууд нь интеграцийн хөндлөн гулд нямбай, тэгш бус "тохирохгүй" гэдгийг илтгэнэ. Тиймээс гиперпараметрийн энэ тохиргоог хүчингүй гэж үздэг бөгөөд ConvNet номын сан нь үүнийг тохируулахын тулд бусад нь онцгой эсвэл 0 хавтанг шидэж болно, эсвэл тохируулахын тулд оролтыг хурааж болно, эсвэл ямар нэгэн зүйл. ConvNet архитектурын хэсгээс харахад, ConvNets-ийг зохих ёсоор томруулна. Ингэснээр бүх хэмжээс "ажиллах" нь жинхэнэ толгой өвдөх болно. Энэ нь 0-padding болон зарим дизайны удирдамжийг ашиглах нь ихээхэн хөнгөвчилнө.
#
# Бодит ертөнцийн жишээ. 2012 онд ImageNet challenge-д түрүүлсэн Krizhevsky et al. архитектур нь хэмжээ дүрсийг хүлээн зөвшөөрсөн [227x227x3]. Эхний Convolutional Layer дээр хүлээн авах талбайн хэмжээ F=11, stride S=4and no zero padding P=0 нейронуудыг ашигласан. (227 - 11)/4 + 1 = 55-аас хойш, Конв давхарга нь К=96-ийн гүнтэй байсан тул Конв давхаргын гаралтын хэмжээ хэмжээ нь [55x5x96]. Энэ ботийн 55\*55\*96 нейрон тус бүр нь оролтын хэмжээнд [11x11x3] хэмжээтэй бүсэд холбогдсон байна. Түүнээс гадна, гүн багана бүрийн 96 нейронууд бүгд оролтын ижил [11x11x3] бүсэд холбогдсон байдаг ч мэдээж өөр өөр жинтэй байдаг. Зугаа цэнгэлийн хувьд, хэрэв та жинхэнэ цаасыг уншвал оролтын дүрсүүд 224х224 байсан гэж мэдэгдэж байна. Энэ нь гарцаагүй буруу юм. Учир нь (224 - 11)/4 + 1 нь интегер биш гэдэг нь тодорхой. Энэ нь ConvNets-ийн түүхэн дэх олон хүнийг будлиулсан бөгөөд юу болсныг бараг мэддэггүй. Миний өөрийн хамгийн сайн таамаглал бол Алекс судалгаан дээр дурдаагүй 3 нэмэлт пикселийн нөлөөг ашигласан явдал юм.
#
#
# Параметр хуваалцах. Параметр хуваалцах схемийг Convolutional Layers-д параметрүүдийн тоог хянахад ашигладаг. Дээрх бодит ертөнцийн жишээг ашиглан бид анхны Conv Layer-д 55\*55\*96 = 290,400 нейронууд байгаа бөгөөд тус бүр нь 11\*11\*3 = 363 жин, 1 биастай гэж харж байна. Энэ нь хамтдаа зөвхөн ConvNet-ийн эхний давхарга дээр 290400 \* 364 = 105,705,600 параметрүүдийг нэмдэг. Энэ тоо маш өндөр байгаа нь тодорхой.
#
# Бид нэг үндэслэлтэй таамаглал дэвшүүлснээр параметрүүдийн тоог эрс багасгаж чадна гэдэг нь харагдаж байна. Хэрэв нэг онцлог нь ямар нэг орон зайн байрлалаар (x,y) тооцоолоход ашигтай бол өөр байрлалаар (x2,y2) тооцоолох нь бас ашигтай байх ёстой. Өөрөөр хэлбэл, нэг 2 хэмжээст гүнийг гүн хальс гэж (жишээ нь: хэмжээ нь [55х5х96] 96 гүн ширхэгтэй, тус бүр нь [55х55] хэмжээтэй) гэсэн үг юм. Бид гүн ширхэг бүрийн нейронуудыг ижил жин, тал тохой ашиглахыг хязгаарлах гэж байна. Энэ параметр хуваалцах схемээр бидний жишээн дэх анхны Conv Layer одоо ердөө 96 өвөрмөц багц жинтэй байх (нэг нь гүн ширхэг бүрт), нийт 96\*11\*11\*3 = 34,848 өвөрмөц жин буюу 34,944 параметр (+96 biases) байх болно. Үүнээс гадна, бүх 55*55 нейронууд нь одоо нэг параметрүүдийг ашиглах болно. Практикт backpropagation үед чанга яригч бүр градиентыг жиндээ тооцоолно. Харин эдгээр градиентууд нь гүн хэсэг бүрт нэмж, зөвхөн нэг ширхэг жинг шинэчлэх болно.
#
#
# Хэрэв нэг гүн хэсэг дэх бүх нейронууд ижил жингийн векторыг ашиглаж байгаа бол КОНВ-ийн давхаргын урагшлах дамжуулалтыг оролтын хэмжээ бүхий нейронын жингийн цуваа болгон тооцоолж болно гэдгийг анхаараарай (тиймээс нэр: Convolutional Layer). Тийм ч учраас жин багцуудыг шүүлтүүр (эсвэл кернель) гэж нэрлэх нь түгээмэл байдаг. Энэ нь оролттой нийлэгждэг.
#
# ![Alt Text](https://cs231n.github.io/assets/cnn/weights.jpeg)
#
# Крижевскийн et al-ийн сурсан жишээ шүүлтүүрүүд. Энд үзүүлсэн 96 ширхэг шүүлтүүр тус бүр нь хэмжээ нь [11x11x3] бөгөөд тус бүр нь нэг гүн ширхэгт 55\*55 нейронууд хуваалцдаг. Параметрийг хуваалцах таамаглал харьцангуй үндэслэлтэй гэдгийг анхаараарай. Хэрэв зургийн аль нэг газарт хөндлөн ирмэгийг илрүүлэх нь чухал юм бол энэ нь өөр ямар нэг газарт ч мөн мэдрэмтгий байх ёстой. Учир нь дүрсүүдийн орчуулгын инварит бүтэцтэй холбоотойгоор. Тиймээс Conv давхаргын гаралтын хэмжээн дэх 55*55 ялгаатай байрлал бүрт хөндлөн ирмэгийг илрүүлэхийн тулд дахин сурах шаардлагагүй.

# %% [markdown]
# ![Alt Text](https://cdn-media-1.freecodecamp.org/images/gb08-2i83P5wPzs3SL-vosNb6Iur5kb5ZH43)

# %% [markdown]
# Backpropagation. Конволюцийн процессийн (өгөгдөл болон жингийн аль алиных нь хувьд) буцах урсгал нь мөн л конволюц (гэхдээ орон зайгаар эргэдэг шүүлтүүртэй) юм. Энэ нь 1 хэмжээст тохиолдолд 1 хэмжээстийг 1-ийн жишээгээр авахад хялбар байдаг.
#
# 1х1-ийн конволюц. Үүнээс гадна хэд хэдэн судалгаанд 1x1 конволюцийг ашигласан. Зарим хүмүүс эхлээд 1x1 конволютыг ялангуяа дохио боловсруулалтаас ирсэн үед харахдаа эргэлзэж тээнэгэлздэг. Ер нь сигнал нь 2 хэмжээст тул 1x1 конволют нь утгагүй (энэ нь зүгээр л цэгийн хэмжүүр). Гэсэн хэдий ч ConvNets-д энэ нь тийм биш юм. Учир нь бид 3 хэмжээст хэмжээнээс илүү ажилладаг гэдгийг санах ёстой бөгөөд шүүлтүүрүүд нь оролтын хэмжээг үргэлж бүрэн гүнзгийгээр сунгадаг. Жишээлбэл, оролт нь [32х32x3] байвал 1x1 конволют хийх нь 3 хэмжээст цэгийн бүтээгдэхүүн (оролтын гүн нь 3 сувагтай тул) үр дүнтэй байх болно.
#
# Dilated convolutions. Саяхны нэгэн ололт (жишээ нь Fisher Yu, Vladlen Koltun судалгааг харна уу) нь dilation хэмээх CONV давхаргад дахиад нэг гиперпараметерийг танилцуулах явдал юм. Одоогоор бид зөвхөн contiguous байгаа CONV шүүлтүүрийн талаар ярилцсан. Гэсэн хэдий ч, dilation гэж нэрлэгдэх эс бүрийн хооронд зайтай шүүлтүүртэй байх боломжтой. Жишээ нь нэг хэмжээст 3 хэмжээтэй шүүлтүүр w нь оролт x-ийн дээр тооцоолно: $$ w[0]*x[0] + w[1]*x[1] + w[2]*x[2] $$ . Энэ бол 0-ийн дилаци юм. 1-р дилацийн хувьд шүүлтүүр нь оронд нь $$ w[0]*x[0] + w[1]*x[2] + w[2]*x[4] $$ -ийг тооцоолно; Өөрөөр хэлбэл хэрэглээний хооронд 1-ийн ялгаа байдаг. Энэ нь 0-дипляцтай шүүлтүүртэй хослуулан ашиглах зарим тохиргоонуудад маш их ашиг тустай байж болно. Учир нь энэ нь оролтуудаар орон зайн мэдээллийг илүү хатуугаар цөөн давхаргатай нэгтгэх боломжийг олгодог. Жишээ нь, хэрэв та хоёр 3x3 CONV давхаргыг бие биенийхээ дээр давхарлах юм бол 2-р давхарга дээрх нейронууд нь оролтын 5х5 патчын функц гэдгийг өөртөө итгүүлж болно (бид эдгээр нейронуудын үр дүнтэй хүлээн авах талбар нь 5x5 гэж хэлэх болно). Хэрэв бид dilation конволюцийг ашиглавал энэ үр дүнтэй хүлээн авах талбар илүү хурдан сурах болно.

# %%
class ConvLayer:
    def __init__(self, filter_dim = 3, stride = 1, pad = 1, alpha=0.01):
        self.filter_dim = filter_dim
        self.stride = stride
        self.filter = np.random.randn(self.filter_dim, self.filter_dim)
        self.filter = self.filter/self.filter.sum()
        self.bias = np.random.rand()/10
        self.pad = pad
        self.alpha = alpha

    def convolving(self, X, fil, dimen_x, dimen_y):
        z = np.zeros((dimen_x, dimen_y))
        for i in range(dimen_x):
            for ii in range(dimen_y):
                # temp = None
                x0 = i * self.stride
                y0 = ii * self.stride
                temp = np.multiply(
                    X[x0:x0 + self.filter_dim, y0:y0 + self.filter_dim],
                    fil
                )
                z[i,ii] = temp.sum()
        return z
        
    def forward_pass(self, X):
        self.X = X
        (d, p, t) = self.X.shape
        dimen_x = int(((p - self.filter_dim)/self.stride) + 1)
        dimen_y = int(((t - self.filter_dim)/self.stride) + 1)
        self.z = np.zeros((d, dimen_x, dimen_y))
        for i in range(d):
            # self.z[i] = None
            self.z[i] = self.convolving(self.X[i], self.filter, dimen_x, dimen_y) + self.bias

        return self.z

    def backprop(self, grad_z):
        (d, p, t) = grad_z.shape
        filter_1 = np.flip((np.flip(self.filter, axis = 0)), axis = 1)
        self.grads = np.zeros((d, p, t))
        for i in range(d):
            self.grads[i] = self.convolving(np.pad(grad_z[i], ((1,1), (1,1)), 'constant', constant_values = 0), filter_1, p, t)

        self.grads = np.pad(self.grads, ((0,0),(1,1),(1,1)), 'constant', constant_values = 0)

        self.grad_filter = np.zeros((self.filter_dim, self.filter_dim))

        for i in range(self.filter_dim):
            for ii in range(self.filter_dim):
                self.grad_filter[i, ii] = (np.multiply(grad_z, self.X[:, i:p+i, ii:t+ii])).sum()
        self.grad_filter = self.grad_filter/(d*grad_z.shape[1]*grad_z.shape[2])

        self.grad_bias = (grad_z.sum())/(d*grad_z.shape[1]*grad_z.shape[2])
        return self.grads

    def applying_sgd(self):
        # self.filter = None
        # self.bias = None
        self.filter = self.filter - self.alpha * self.grad_filter
        self.bias = self.bias - self.alpha * self.grad_bias

    def change_alpha(self):
        self.alpha = self.alpha/10

# %% [markdown]
# ## Даалгавар
#
# 1. Кодыг гүйцээн ажиллуулах
# 2. Олон кернэл дээр ажилладаг болгох

# %% [markdown]
# ## Pooling давхрага
# ![Alt Text](https://miro.medium.com/v2/resize:fit:720/format:webp/1*fXxDBsJ96FKEtMOa9vNgjA.gif)
#
#
# ConvNet архитектурт дараалсан Conv давхаргуудын хооронд pooling давхаргыг үе үе оруулах нь түгээмэл байдаг. Түүний функц нь сүлжээн дэх параметр, тооцооллын хэмжээг багасгахын тулд төлөөллийн орон зайн хэмжээг аажмаар багасгах, улмаар тооцооллыг хянах явдал юм. Pooling Layer нь оролтын гүн ширхэг бүр дээр бие даан ажиллаж, MAX-ийн үйл ажиллагааг ашиглан орон зайгаар дахин хийдэг. Хамгийн түгээмэл хэлбэр нь 2х2 хэмжээтэй шүүлтүүртэй Pool давхарга юм. Оролтод орсон гүн хэсэг бүрийг 2-оор нь өргөн, өндрийн аль алинаар нь 2-оор доош буулгаж, идэвхжүүлэлтийн 75%-ийг хаядаг. Энэ тохиолдолд MAX-ийн process бүр нь 4 тооноос дээш (ямар нэг гүнзгий хэсэгт 2x2 бүс) дээд утгыг авах болно. Энд гүн хэмжээс нь өөрчлөгдөөгүй хэвээр байна. Ерөнхийдөө:
# -	W1×H1×D1 хэмжээтэй томъёог хүлээн зөвшөөрч байна
# -	Хоёр гиперпараметр шаардлагатай:
# -	тэдний орон зайн хэмжээ F,
# -   S-ийн алхаа,
# -	W2×H2×D2 хэмжээтэй хэмжээс гаргадаг. Хаана:
# -	W2=(W1−F)/S+1
# -	H2=(H1−F)/S+1
# -	D2=D1
# -	Оролтын тогтмол функцийг тооцоолсноос хойш 0 параметрүүдийг гаргадаг
# Pooling layers-ийн хувьд оролтыг zero-padding ашиглан pad хийх нь түгээмэл биш юм. Практикт олдсон max pooling давхаргын хоёр л нийтлэг харагддаг хувьсал байдаг гэдгийг анхаарах нь зүйтэй. Үүнд: F=3,S=2 (мөн давхар усан сан гэж нэрлэдэг), мөн илүү түгээмэл F=2, S=2-той Pool-ийн давхарга. Илүү том хүлээн авах талбайтай Pool хэт хөнөөлтэй.

# %%
class Pooling:
    def __init__(self, pool_dim=2, stride=2):
        self.pool_dim = pool_dim
        self.stride = stride
    
    def forward_pass(self, data):
        (q, p, t) = data.shape

        z_x = int((p - self.pool_dim) / self.stride) + 1
        z_y = int((t - self.pool_dim) / self.stride) + 1

        after_pool = np.zeros((q, z_x, z_y))
        
        for ii in range(0, q):
            liss = []
            for i in range(0, p, self.stride):
                for j in range(0, t, self.stride):
                    if (i + self.pool_dim <= p) and (j + self.pool_dim <= t):
                        temp = data[ii, i:i + self.pool_dim, j:j + self.pool_dim]
                        temp_1 = np.max(temp)
                        liss.append(temp_1)
            liss = np.asarray(liss)
            liss = liss.reshape((z_x, z_y))
            after_pool[ii] = liss
            del liss
        return after_pool
    
    def backprop(self, pooled):
        (a, b, c) = pooled.shape
        cheated = np.zeros((a, 2 * b, 2 * c))
        for k in range(0, a):
            pooled_transpose_re = pooled[k].reshape((b * c))
            count = 0
            for i in range(0, 2 * b, self.stride):
                for j in range(0, 2 * c, self.stride):
                    cheated[k, i:i + self.stride, j:j + self.stride] = pooled_transpose_re[count]
                    count = count + 1
        return cheated
    
    def applying_sgd(self):
        pass

# %% [markdown]
# ## Softmax
#
# Шууд чиглэл
#
#
# ![Alt Text](https://e2eml.school/images/softmax/def_01_eq.png)
#
#
# Буцах чиглэл
#
# ![Alt Text](https://e2eml.school/images/softmax/d_softmax_03.png)

# %%
class softmax:
    def __init__(self):
        pass
    def expansion(self, t):
        (a,) = t.shape
        Y = np.zeros((a,10))
        for i in range(0,a):
            Y[i,t[i]] = 1
        return Y
    def forward_pass(self, z):
        self.z =  z

        # (p,t) = self.z.shape
        # self.a = np.zeros((p,t))
        # for i in range(0,p):
        #     for ii in range(0,t):
        #         self.a[i,ii] = None #

        z_shift = z - np.max(z, axis=1, keepdims=True)
        exp_z = np.exp(z_shift)
        self.a = exp_z / np.sum(exp_z, axis=1, keepdims=True)
        return self.a
        
    def backprop(self, Y):
        y = self.expansion(Y)
        self.grad = (self.a - y)
        return self.grad
    def applying_sgd(self):
        pass

# %%
class relu:
    def __init__(self):
        pass
    def forward_pass(self, z):
        if (len(z.shape) == 3):
            z_temp = z.reshape((z.shape[0], z.shape[1]*z.shape[2]))
            z_temp_1 = self.forward_pass(z_temp)
            self.a_1 = z_temp_1.reshape((z.shape[0], z.shape[1], z.shape[2]))
            return (self.a_1)
        else:
            (p,t) = z.shape
            self.a = np.zeros((p,t))
            for i in range(0,p):
                for ii in range(0,t):
                        self.a[i,ii] = max([0,z[i,ii]])
            return self.a
    def derivative(self, a):
        if a>0:
            return 1
        else:
            return 0
    def backprop(self, grad_previous):
        if (len(grad_previous.shape)==3):
            (d, p, t) = grad_previous.shape
            self.grad = np.zeros((d, p, t))
            for i in range(d):
                for ii in range(p):
                    for iii in range(t):
                        self.grad[i, ii, iii] = (grad_previous[i, ii, iii] * self.derivative(self.a_1[i, ii, iii]))
            return (self.grad)
        else:
            (p,t) = grad_previous.shape
            self.grad = np.zeros((p, t))
            for i in range(p):
                for ii in range(t):
                    self.grad[i, ii] = grad_previous[i, ii] * self.derivative(self.a[i, ii])
            return self.grad
            
            _ # (p,t) = self.z.shape
        # self.a = np.zeros((p,t))
        # for i in range(0,p):
        #     for ii in range(0,t):
        #         self.a[i,ii] = None #previous.shape
        
    def applying_sgd(self):
        pass

    
class padding():
    def __init__(self, pad = 1):
        self.pad = pad
    def forward_pass(self, data):
        X = np.pad(data , ((0, 0), (self.pad, self.pad), (self.pad, self.pad)),'constant', constant_values=0)
        return X
    def backprop(self, y):
        return (y[:, 1:(y.shape[1]-1),1:(y.shape[2]-1)])
    def applying_sgd(self):
        pass


class reshaping:
    def __init__(self):
        pass
    def forward_pass(self, a):
        self.shape_a = a.shape
        self.final_a = a.reshape(self.shape_a[0], self.shape_a[1]*self.shape_a[2])
        return self.final_a
    def backprop(self, q):
        return (q.reshape(self.shape_a[0], self.shape_a[1], self.shape_a[2]))
    def applying_sgd(self):
        pass

class cross_entropy:
    def __init__(self):
        pass
    def expansion(self, t):
        (a,) = t.shape
        Y = np.zeros((a,10))
        for i in range(0,a):
            Y[i,t[i]] = 1
        return Y
    def loss(self, A, Y):
        eps = 1e-8
        A = np.clip(A, eps, 1 - eps)

        exp_Y = self.expansion(Y)
        (u,i) = A.shape
        loss_matrix = np.zeros((u,i))
        for j in range(u):
            for jj in range(i):
                if exp_Y[j,jj] == 0:
                    loss_matrix[j,jj] = np.log(1 - A[j,jj])
                else:
                    loss_matrix[j,jj] = np.log(A[j,jj])
        return ((-(loss_matrix.sum()))/u)

class accuracy:
    def __init__(self):
        pass
    def value(self, out, Y):
        self.out = np.argmax(out, axis=1)
        p = self.out.shape[0]
        total = 0
        for i in range(p):
            if Y[i]==self.out[i]:
                total += 1
        return total/p

class ConvNet:
    def __init__(self, Network):
        self.Network = Network
    def forward_pass(self, X):
        n = X
        for i in self.Network:
            n = i.forward_pass(n)
            # print(n.shape) #
        return n
    def backprop(self, Y):
        m = Y
        count = 1
        for i in (reversed(self.Network)):
            m = i.backprop(m)
    def applying_sgd(self):
        for i in self.Network:
            i.applying_sgd()

# %%
(Xtr, Ytr), (Xte, Yte) = Mnist.load_data()
X_training = Xtr[:1000,:,:]
Y_training = Ytr[:1000]
X_training = X_training/255
al = 0.3
stopper = 85.0

complete_NN = ConvNet([
                        padding(),
                        ConvLayer(),
                        Pooling(),
                        relu(),

                        padding(),
                        ConvLayer(),
                        Pooling(),
                        relu(),

                        ConvLayer(),
                        relu(),
                        
                        reshaping(),
                        Linear_Layer(5*5, 24, alpha = al),
                        relu(),
                        Linear_Layer(24, 10, alpha = al),
                        softmax()])


CE = cross_entropy()
acc = accuracy()
epochs = 30
broke = 0
batches = 100
for i in range(epochs):
    k = 0
    for j in range(batches, 1001, batches):
        out = complete_NN.forward_pass(X_training[k:j])
        print("epoch:{} \t batch: {} \t loss: \t {}".format(i+1, int(j/batches), CE.loss(out, Y_training[k:j])), end="\t")
        accur = acc.value(out, Y_training[k:j])*100
        print("accuracy: {}".format(accur))
        # break #
        if accur >= stopper:
            broke = 1
            break
        complete_NN.backprop(Y_training[k:j])
        complete_NN.applying_sgd()
        k = j
    if broke == 1:
        break
    
out = complete_NN.forward_pass(X_training)
print("The final loss is {}".format(CE.loss(out, Y_training)))
print("The final accuracy on train set is {}".format(acc.value(out, Y_training)*100))
# Xtest = Xte/255
# out_1 = complete_NN.forward_pass(Xtest)
# print("The accuracy on test set is {}".format(acc.value(out_1, Yte)*100))
# Out:
# epoch:1 	 batch: 1 	 loss: 	 3.4086005816125384	accuracy: 9.0
# epoch:1 	 batch: 2 	 loss: 	 3.2941078549029776	accuracy: 8.0
# epoch:1 	 batch: 3 	 loss: 	 3.2064823483384703	accuracy: 9.0
# epoch:1 	 batch: 4 	 loss: 	 3.255200930811731	accuracy: 15.0
# epoch:1 	 batch: 5 	 loss: 	 3.2141744300985042	accuracy: 11.0
# epoch:1 	 batch: 6 	 loss: 	 3.053971458830316	accuracy: 22.0
# epoch:1 	 batch: 7 	 loss: 	 3.046449537894738	accuracy: 28.999999999999996
# epoch:1 	 batch: 8 	 loss: 	 3.1228519116164852	accuracy: 24.0
# epoch:1 	 batch: 9 	 loss: 	 3.0464490229900285	accuracy: 18.0
# epoch:1 	 batch: 10 	 loss: 	 3.036962398286459	accuracy: 23.0
# epoch:2 	 batch: 1 	 loss: 	 2.883788713705585	accuracy: 28.999999999999996
# epoch:2 	 batch: 2 	 loss: 	 2.944632914664504	accuracy: 28.999999999999996
# epoch:2 	 batch: 3 	 loss: 	 2.8143524620805223	accuracy: 37.0
# epoch:2 	 batch: 4 	 loss: 	 2.8762415287439267	accuracy: 40.0
# epoch:2 	 batch: 5 	 loss: 	 2.8700341203632114	accuracy: 28.000000000000004
# epoch:2 	 batch: 6 	 loss: 	 2.717216402634406	accuracy: 42.0
# epoch:2 	 batch: 7 	 loss: 	 2.6982602569823166	accuracy: 47.0
# epoch:2 	 batch: 8 	 loss: 	 2.7696054944974877	accuracy: 37.0
# epoch:2 	 batch: 9 	 loss: 	 2.698524292834733	accuracy: 36.0
# epoch:2 	 batch: 10 	 loss: 	 2.7008891652176703	accuracy: 45.0
# epoch:3 	 batch: 1 	 loss: 	 2.5055732965706334	accuracy: 48.0
# epoch:3 	 batch: 2 	 loss: 	 2.570848774946187	accuracy: 51.0
# epoch:3 	 batch: 3 	 loss: 	 2.434513693575431	accuracy: 51.0
# epoch:3 	 batch: 4 	 loss: 	 2.5389685077441237	accuracy: 50.0
# epoch:3 	 batch: 5 	 loss: 	 2.541397128056425	accuracy: 48.0
# epoch:3 	 batch: 6 	 loss: 	 2.3639976963298155	accuracy: 49.0
# epoch:3 	 batch: 7 	 loss: 	 2.3338417316543714	accuracy: 62.0
# epoch:3 	 batch: 8 	 loss: 	 2.390682577439334	accuracy: 51.0
# epoch:3 	 batch: 9 	 loss: 	 2.3725316023291416	accuracy: 49.0
# epoch:3 	 batch: 10 	 loss: 	 2.3725288579866928	accuracy: 51.0
# epoch:4 	 batch: 1 	 loss: 	 2.183004890573892	accuracy: 57.99999999999999
# epoch:4 	 batch: 2 	 loss: 	 2.2362676770826964	accuracy: 62.0
# epoch:4 	 batch: 3 	 loss: 	 2.072185936513035	accuracy: 55.00000000000001
# epoch:4 	 batch: 4 	 loss: 	 2.1787122744077014	accuracy: 64.0
# epoch:4 	 batch: 5 	 loss: 	 2.1952667151530907	accuracy: 52.0
# epoch:4 	 batch: 6 	 loss: 	 2.072056543031761	accuracy: 55.00000000000001
# epoch:4 	 batch: 7 	 loss: 	 2.040276816070902	accuracy: 65.0
# epoch:4 	 batch: 8 	 loss: 	 2.067687698004835	accuracy: 60.0
# epoch:4 	 batch: 9 	 loss: 	 2.120365704440883	accuracy: 54.0
# epoch:4 	 batch: 10 	 loss: 	 2.121589810653687	accuracy: 55.00000000000001
# epoch:5 	 batch: 1 	 loss: 	 1.9474191988891405	accuracy: 64.0
# epoch:5 	 batch: 2 	 loss: 	 1.971009630975052	accuracy: 65.0
# epoch:5 	 batch: 3 	 loss: 	 1.7941550103484836	accuracy: 63.0
# epoch:5 	 batch: 4 	 loss: 	 1.8903504108023237	accuracy: 65.0
# epoch:5 	 batch: 5 	 loss: 	 1.9212297177176503	accuracy: 59.0
# epoch:5 	 batch: 6 	 loss: 	 1.8448971719373273	accuracy: 65.0
# epoch:5 	 batch: 7 	 loss: 	 1.8294202079164665	accuracy: 66.0
# epoch:5 	 batch: 8 	 loss: 	 1.832253869126112	accuracy: 63.0
# epoch:5 	 batch: 9 	 loss: 	 1.9560284642681665	accuracy: 57.99999999999999
# epoch:5 	 batch: 10 	 loss: 	 1.949296141854914	accuracy: 59.0
# epoch:6 	 batch: 1 	 loss: 	 1.7822293160669822	accuracy: 69.0
# epoch:6 	 batch: 2 	 loss: 	 1.7723037316453558	accuracy: 69.0
# epoch:6 	 batch: 3 	 loss: 	 1.608833836542188	accuracy: 63.0
# epoch:6 	 batch: 4 	 loss: 	 1.6952459149953558	accuracy: 68.0
# epoch:6 	 batch: 5 	 loss: 	 1.7186572077819318	accuracy: 67.0
# epoch:6 	 batch: 6 	 loss: 	 1.67442589672133	accuracy: 66.0
# epoch:6 	 batch: 7 	 loss: 	 1.6718252600406338	accuracy: 68.0
# epoch:6 	 batch: 8 	 loss: 	 1.6508584141178977	accuracy: 67.0
# epoch:6 	 batch: 9 	 loss: 	 1.8194720443250734	accuracy: 60.0
# epoch:6 	 batch: 10 	 loss: 	 1.8318671828630013	accuracy: 57.99999999999999
# epoch:7 	 batch: 1 	 loss: 	 1.6686014334044474	accuracy: 68.0
# epoch:7 	 batch: 2 	 loss: 	 1.629378666314401	accuracy: 71.0
# epoch:7 	 batch: 3 	 loss: 	 1.4840748965526904	accuracy: 67.0
# epoch:7 	 batch: 4 	 loss: 	 1.570405139830332	accuracy: 68.0
# epoch:7 	 batch: 5 	 loss: 	 1.5723233735563764	accuracy: 73.0
# epoch:7 	 batch: 6 	 loss: 	 1.5480574447299265	accuracy: 71.0
# epoch:7 	 batch: 7 	 loss: 	 1.5550471601887472	accuracy: 70.0
# epoch:7 	 batch: 8 	 loss: 	 1.522628807300552	accuracy: 71.0
# epoch:7 	 batch: 9 	 loss: 	 1.6993130510648626	accuracy: 65.0
# epoch:7 	 batch: 10 	 loss: 	 1.7492171611594984	accuracy: 62.0
# epoch:8 	 batch: 1 	 loss: 	 1.6355511330228796	accuracy: 64.0
# epoch:8 	 batch: 2 	 loss: 	 1.5525869326056894	accuracy: 70.0
# epoch:8 	 batch: 3 	 loss: 	 1.4266720337003347	accuracy: 65.0
# epoch:8 	 batch: 4 	 loss: 	 1.482168420205599	accuracy: 69.0
# epoch:8 	 batch: 5 	 loss: 	 1.4503537026344853	accuracy: 75.0
# epoch:8 	 batch: 6 	 loss: 	 1.4577737114987586	accuracy: 71.0
# epoch:8 	 batch: 7 	 loss: 	 1.4690856094480396	accuracy: 73.0
# epoch:8 	 batch: 8 	 loss: 	 1.4424500370534867	accuracy: 72.0
# epoch:8 	 batch: 9 	 loss: 	 1.6318151974946524	accuracy: 66.0
# epoch:8 	 batch: 10 	 loss: 	 1.683119131917668	accuracy: 63.0
# epoch:9 	 batch: 1 	 loss: 	 1.5960009936292148	accuracy: 65.0
# epoch:9 	 batch: 2 	 loss: 	 1.4788283360580683	accuracy: 70.0
# epoch:9 	 batch: 3 	 loss: 	 1.3635053878877406	accuracy: 69.0
# epoch:9 	 batch: 4 	 loss: 	 1.41632346523132	accuracy: 71.0
# epoch:9 	 batch: 5 	 loss: 	 1.3637605909280537	accuracy: 77.0
# epoch:9 	 batch: 6 	 loss: 	 1.3960300598993731	accuracy: 72.0
# epoch:9 	 batch: 7 	 loss: 	 1.3953067635355827	accuracy: 73.0
# epoch:9 	 batch: 8 	 loss: 	 1.367601976439446	accuracy: 73.0
# epoch:9 	 batch: 9 	 loss: 	 1.566701398420785	accuracy: 66.0
# epoch:9 	 batch: 10 	 loss: 	 1.605426561778148	accuracy: 66.0
# epoch:10 	 batch: 1 	 loss: 	 1.4969429244731276	accuracy: 69.0
# epoch:10 	 batch: 2 	 loss: 	 1.3737041624075295	accuracy: 72.0
# epoch:10 	 batch: 3 	 loss: 	 1.2819554587631672	accuracy: 68.0
# epoch:10 	 batch: 4 	 loss: 	 1.3621949426038027	accuracy: 71.0
# epoch:10 	 batch: 5 	 loss: 	 1.3001250737583447	accuracy: 76.0
# epoch:10 	 batch: 6 	 loss: 	 1.3461451255164059	accuracy: 74.0
# epoch:10 	 batch: 7 	 loss: 	 1.3346914488732824	accuracy: 73.0
# epoch:10 	 batch: 8 	 loss: 	 1.2997225955180227	accuracy: 74.0
# epoch:10 	 batch: 9 	 loss: 	 1.5156381147085352	accuracy: 68.0
# epoch:10 	 batch: 10 	 loss: 	 1.5342986997516885	accuracy: 68.0
# epoch:11 	 batch: 1 	 loss: 	 1.4134516086364985	accuracy: 72.0
# epoch:11 	 batch: 2 	 loss: 	 1.2977543811198473	accuracy: 71.0
# epoch:11 	 batch: 3 	 loss: 	 1.2232800583618524	accuracy: 70.0
# epoch:11 	 batch: 4 	 loss: 	 1.3127607105777575	accuracy: 73.0
# epoch:11 	 batch: 5 	 loss: 	 1.2458189699815712	accuracy: 77.0
# epoch:11 	 batch: 6 	 loss: 	 1.3077644064896001	accuracy: 73.0
# epoch:11 	 batch: 7 	 loss: 	 1.2853216282455153	accuracy: 73.0
# epoch:11 	 batch: 8 	 loss: 	 1.2409640129965365	accuracy: 76.0
# epoch:11 	 batch: 9 	 loss: 	 1.4827929062831913	accuracy: 69.0
# epoch:11 	 batch: 10 	 loss: 	 1.4780506614459543	accuracy: 69.0
# epoch:12 	 batch: 1 	 loss: 	 1.3541167202041913	accuracy: 74.0
# epoch:12 	 batch: 2 	 loss: 	 1.2391129674376273	accuracy: 73.0
# epoch:12 	 batch: 3 	 loss: 	 1.1823961303728199	accuracy: 72.0
# epoch:12 	 batch: 4 	 loss: 	 1.2841016683529305	accuracy: 75.0
# epoch:12 	 batch: 5 	 loss: 	 1.1944980162181518	accuracy: 77.0
# epoch:12 	 batch: 6 	 loss: 	 1.279841736868975	accuracy: 76.0
# epoch:12 	 batch: 7 	 loss: 	 1.2485566095521634	accuracy: 76.0
# epoch:12 	 batch: 8 	 loss: 	 1.186480090510394	accuracy: 77.0
# epoch:12 	 batch: 9 	 loss: 	 1.4413902147949131	accuracy: 70.0
# epoch:12 	 batch: 10 	 loss: 	 1.4307971222004559	accuracy: 70.0
# epoch:13 	 batch: 1 	 loss: 	 1.3205643505526075	accuracy: 73.0
# epoch:13 	 batch: 2 	 loss: 	 1.2007996145251638	accuracy: 75.0
# epoch:13 	 batch: 3 	 loss: 	 1.1555998604779427	accuracy: 72.0
# epoch:13 	 batch: 4 	 loss: 	 1.2450541012907184	accuracy: 78.0
# epoch:13 	 batch: 5 	 loss: 	 1.1532679652391753	accuracy: 78.0
# epoch:13 	 batch: 6 	 loss: 	 1.2501298654307282	accuracy: 77.0
# epoch:13 	 batch: 7 	 loss: 	 1.2135013762662656	accuracy: 75.0
# epoch:13 	 batch: 8 	 loss: 	 1.148709822508336	accuracy: 79.0
# epoch:13 	 batch: 9 	 loss: 	 1.3987368889073477	accuracy: 71.0
# epoch:13 	 batch: 10 	 loss: 	 1.3878574557352243	accuracy: 72.0
# epoch:14 	 batch: 1 	 loss: 	 1.325027260131477	accuracy: 72.0
# epoch:14 	 batch: 2 	 loss: 	 1.1880481939524465	accuracy: 76.0
# epoch:14 	 batch: 3 	 loss: 	 1.1449756758511613	accuracy: 71.0
# epoch:14 	 batch: 4 	 loss: 	 1.207100563583175	accuracy: 78.0
# epoch:14 	 batch: 5 	 loss: 	 1.112450552568514	accuracy: 79.0
# epoch:14 	 batch: 6 	 loss: 	 1.220745533767897	accuracy: 80.0
# epoch:14 	 batch: 7 	 loss: 	 1.1865985316970893	accuracy: 77.0
# epoch:14 	 batch: 8 	 loss: 	 1.1226638052189712	accuracy: 80.0
# epoch:14 	 batch: 9 	 loss: 	 1.3670990601245754	accuracy: 70.0
# epoch:14 	 batch: 10 	 loss: 	 1.3416210215186106	accuracy: 74.0
# epoch:15 	 batch: 1 	 loss: 	 1.300373761636469	accuracy: 72.0
# epoch:15 	 batch: 2 	 loss: 	 1.1590011296846237	accuracy: 79.0
# epoch:15 	 batch: 3 	 loss: 	 1.1171774395350897	accuracy: 72.0
# epoch:15 	 batch: 4 	 loss: 	 1.1700802337145182	accuracy: 79.0
# epoch:15 	 batch: 5 	 loss: 	 1.0781296341030222	accuracy: 78.0
# epoch:15 	 batch: 6 	 loss: 	 1.1988639618300754	accuracy: 79.0
# epoch:15 	 batch: 7 	 loss: 	 1.1623034852843517	accuracy: 77.0
# epoch:15 	 batch: 8 	 loss: 	 1.0956039201527161	accuracy: 80.0
# epoch:15 	 batch: 9 	 loss: 	 1.3379232189719692	accuracy: 72.0
# epoch:15 	 batch: 10 	 loss: 	 1.3092891975135688	accuracy: 75.0
# epoch:16 	 batch: 1 	 loss: 	 1.2806922634005429	accuracy: 73.0
# epoch:16 	 batch: 2 	 loss: 	 1.1242672200325894	accuracy: 79.0
# epoch:16 	 batch: 3 	 loss: 	 1.0857477758919252	accuracy: 73.0
# epoch:16 	 batch: 4 	 loss: 	 1.1371155601255556	accuracy: 80.0
# epoch:16 	 batch: 5 	 loss: 	 1.0483196415642262	accuracy: 79.0
# epoch:16 	 batch: 6 	 loss: 	 1.178266900333903	accuracy: 81.0
# epoch:16 	 batch: 7 	 loss: 	 1.1407533519474222	accuracy: 78.0
# epoch:16 	 batch: 8 	 loss: 	 1.064094346793689	accuracy: 80.0
# epoch:16 	 batch: 9 	 loss: 	 1.3079864182234582	accuracy: 73.0
# epoch:16 	 batch: 10 	 loss: 	 1.2713992658305715	accuracy: 75.0
# epoch:17 	 batch: 1 	 loss: 	 1.2388947763299307	accuracy: 74.0
# epoch:17 	 batch: 2 	 loss: 	 1.0882375106582929	accuracy: 80.0
# epoch:17 	 batch: 3 	 loss: 	 1.0561817225530539	accuracy: 76.0
# epoch:17 	 batch: 4 	 loss: 	 1.1065515370890642	accuracy: 80.0
# epoch:17 	 batch: 5 	 loss: 	 1.023660980353268	accuracy: 79.0
# epoch:17 	 batch: 6 	 loss: 	 1.1619584655536437	accuracy: 83.0
# epoch:17 	 batch: 7 	 loss: 	 1.1244430673183394	accuracy: 79.0
# epoch:17 	 batch: 8 	 loss: 	 1.0337438198655955	accuracy: 80.0
# epoch:17 	 batch: 9 	 loss: 	 1.281510856365012	accuracy: 73.0
# epoch:17 	 batch: 10 	 loss: 	 1.2381862666773151	accuracy: 77.0
# epoch:18 	 batch: 1 	 loss: 	 1.2094367418560794	accuracy: 75.0
# epoch:18 	 batch: 2 	 loss: 	 1.0601564472713991	accuracy: 80.0
# epoch:18 	 batch: 3 	 loss: 	 1.0353214966545286	accuracy: 76.0
# epoch:18 	 batch: 4 	 loss: 	 1.0799748816117465	accuracy: 83.0
# epoch:18 	 batch: 5 	 loss: 	 1.004432983177395	accuracy: 80.0
# epoch:18 	 batch: 6 	 loss: 	 1.1446765797835101	accuracy: 83.0
# epoch:18 	 batch: 7 	 loss: 	 1.1126441566237442	accuracy: 80.0
# epoch:18 	 batch: 8 	 loss: 	 1.0081701057818873	accuracy: 80.0
# epoch:18 	 batch: 9 	 loss: 	 1.2570393784338807	accuracy: 74.0
# epoch:18 	 batch: 10 	 loss: 	 1.2146438869884806	accuracy: 78.0
# epoch:19 	 batch: 1 	 loss: 	 1.211614763820692	accuracy: 75.0
# epoch:19 	 batch: 2 	 loss: 	 1.0494542569207566	accuracy: 81.0
# epoch:19 	 batch: 3 	 loss: 	 1.0228034199407776	accuracy: 77.0
# epoch:19 	 batch: 4 	 loss: 	 1.0630023550755954	accuracy: 83.0
# epoch:19 	 batch: 5 	 loss: 	 0.9855079630570183	accuracy: 80.0
# epoch:19 	 batch: 6 	 loss: 	 1.1299143768813582	accuracy: 83.0
# epoch:19 	 batch: 7 	 loss: 	 1.0986933519785549	accuracy: 80.0
# epoch:19 	 batch: 8 	 loss: 	 0.9850784696303976	accuracy: 80.0
# epoch:19 	 batch: 9 	 loss: 	 1.233921823613459	accuracy: 75.0
# epoch:19 	 batch: 10 	 loss: 	 1.1841208915045396	accuracy: 80.0
# epoch:20 	 batch: 1 	 loss: 	 1.1713530745568037	accuracy: 75.0
# epoch:20 	 batch: 2 	 loss: 	 1.0232067902716204	accuracy: 81.0
# epoch:20 	 batch: 3 	 loss: 	 1.008644244587518	accuracy: 78.0
# epoch:20 	 batch: 4 	 loss: 	 1.0444939041956147	accuracy: 84.0
# epoch:20 	 batch: 5 	 loss: 	 0.9684304465192807	accuracy: 80.0
# epoch:20 	 batch: 6 	 loss: 	 1.1145291620290632	accuracy: 83.0
# epoch:20 	 batch: 7 	 loss: 	 1.0877892111979544	accuracy: 80.0
# epoch:20 	 batch: 8 	 loss: 	 0.9595333704323536	accuracy: 83.0
# epoch:20 	 batch: 9 	 loss: 	 1.2134484548918882	accuracy: 76.0
# epoch:20 	 batch: 10 	 loss: 	 1.1638289423386754	accuracy: 81.0
# epoch:21 	 batch: 1 	 loss: 	 1.1578412107380078	accuracy: 76.0
# epoch:21 	 batch: 2 	 loss: 	 1.0058880034624536	accuracy: 80.0
# epoch:21 	 batch: 3 	 loss: 	 0.9940126041139993	accuracy: 79.0
# epoch:21 	 batch: 4 	 loss: 	 1.0202650481531694	accuracy: 84.0
# epoch:21 	 batch: 5 	 loss: 	 0.9539941087426462	accuracy: 81.0
# epoch:21 	 batch: 6 	 loss: 	 1.109858319018504	accuracy: 83.0
# epoch:21 	 batch: 7 	 loss: 	 1.0775107023639954	accuracy: 80.0
# epoch:21 	 batch: 8 	 loss: 	 0.9404793865572936	accuracy: 83.0
# epoch:21 	 batch: 9 	 loss: 	 1.1938576633556108	accuracy: 77.0
# epoch:21 	 batch: 10 	 loss: 	 1.1380376394127991	accuracy: 81.0
# epoch:22 	 batch: 1 	 loss: 	 1.1352105181192371	accuracy: 76.0
# epoch:22 	 batch: 2 	 loss: 	 0.9807550829294251	accuracy: 80.0
# epoch:22 	 batch: 3 	 loss: 	 0.9720134643146748	accuracy: 80.0
# epoch:22 	 batch: 4 	 loss: 	 0.997153898468798	accuracy: 85.0
# The final loss is 0.9869626726314629
# The final accuracy on train set is 82.19999999999999

# %%
# kerneliin hemjee baga tohioldol ih zurgandeer undur acc garahgui
(Xtr, Ytr), (Xte, Yte) = Mnist.load_data()
X_training = Xtr[:5000,:,:]
Y_training = Ytr[:5000]
X_training = X_training/255
al = 0.3
stopper = 85.0

complete_NN = ConvNet([
                        padding(),
                        ConvLayer(),
                        Pooling(),
                        relu(),

                        padding(),
                        ConvLayer(),
                        Pooling(),
                        relu(),

                        ConvLayer(),
                        relu(),
                        
                        reshaping(),
                        Linear_Layer(5*5, 24, alpha = al),
                        relu(),
                        Linear_Layer(24, 10, alpha = al),
                        softmax()])


CE = cross_entropy()
acc = accuracy()
epochs = 30
broke = 0
batches = 100
for i in range(epochs):
    k = 0
    for j in range(batches, 1001, batches):
        out = complete_NN.forward_pass(X_training[k:j])
        print("epoch:{} \t batch: {} \t loss: \t {}".format(i+1, int(j/batches), CE.loss(out, Y_training[k:j])), end="\t")
        accur = acc.value(out, Y_training[k:j])*100
        print("accuracy: {}".format(accur))
        # break #
        if accur >= stopper:
            broke = 1
            break
        complete_NN.backprop(Y_training[k:j])
        complete_NN.applying_sgd()
        k = j
    if broke == 1:
        break
    
out = complete_NN.forward_pass(X_training)
print("The final loss is {}".format(CE.loss(out, Y_training)))
print("The final accuracy on train set is {}".format(acc.value(out, Y_training)*100))
# Xtest = Xte/255
# out_1 = complete_NN.forward_pass(Xtest)
# print("The accuracy on test set is {}".format(acc.value(out_1, Yte)*100))
# Out:
# epoch:1 	 batch: 1 	 loss: 	 3.5117172393164537	accuracy: 5.0
# epoch:1 	 batch: 2 	 loss: 	 3.253720658518533	accuracy: 14.000000000000002
# epoch:1 	 batch: 3 	 loss: 	 3.203262067864572	accuracy: 21.0
# epoch:1 	 batch: 4 	 loss: 	 3.2203713266258647	accuracy: 18.0
# epoch:1 	 batch: 5 	 loss: 	 3.1906824249812384	accuracy: 24.0
# epoch:1 	 batch: 6 	 loss: 	 3.217131372918546	accuracy: 14.000000000000002
# epoch:1 	 batch: 7 	 loss: 	 3.1983168357026135	accuracy: 17.0
# epoch:1 	 batch: 8 	 loss: 	 3.2407602793752917	accuracy: 23.0
# epoch:1 	 batch: 9 	 loss: 	 3.190079849463519	accuracy: 22.0
# epoch:1 	 batch: 10 	 loss: 	 3.151842076712946	accuracy: 25.0
# epoch:2 	 batch: 1 	 loss: 	 3.1958471800424757	accuracy: 11.0
# epoch:2 	 batch: 2 	 loss: 	 3.1717761890521556	accuracy: 22.0
# epoch:2 	 batch: 3 	 loss: 	 3.096484065186072	accuracy: 37.0
# epoch:2 	 batch: 4 	 loss: 	 3.102658650961898	accuracy: 36.0
# epoch:2 	 batch: 5 	 loss: 	 3.1007304849961304	accuracy: 38.0
# epoch:2 	 batch: 6 	 loss: 	 3.1376023920213094	accuracy: 28.999999999999996
# epoch:2 	 batch: 7 	 loss: 	 3.127292399498573	accuracy: 26.0
# epoch:2 	 batch: 8 	 loss: 	 3.146303581241343	accuracy: 28.999999999999996
# epoch:2 	 batch: 9 	 loss: 	 3.1117333414291055	accuracy: 27.0
# epoch:2 	 batch: 10 	 loss: 	 3.082874815664503	accuracy: 32.0
# epoch:3 	 batch: 1 	 loss: 	 3.12976229752265	accuracy: 14.000000000000002
# epoch:3 	 batch: 2 	 loss: 	 3.1191514956300637	accuracy: 26.0
# epoch:3 	 batch: 3 	 loss: 	 3.0050368492961748	accuracy: 49.0
# epoch:3 	 batch: 4 	 loss: 	 3.0110839765357724	accuracy: 42.0
# epoch:3 	 batch: 5 	 loss: 	 3.020435640394502	accuracy: 39.0
# epoch:3 	 batch: 6 	 loss: 	 3.0596118157457566	accuracy: 37.0
# epoch:3 	 batch: 7 	 loss: 	 3.053649948931944	accuracy: 28.000000000000004
# epoch:3 	 batch: 8 	 loss: 	 3.053507602955061	accuracy: 36.0
# epoch:3 	 batch: 9 	 loss: 	 3.0325317344004463	accuracy: 28.000000000000004
# epoch:3 	 batch: 10 	 loss: 	 2.9957525424586167	accuracy: 40.0
# epoch:4 	 batch: 1 	 loss: 	 3.053926931462504	accuracy: 19.0
# epoch:4 	 batch: 2 	 loss: 	 3.0568748749103043	accuracy: 33.0
# epoch:4 	 batch: 3 	 loss: 	 2.893261598848793	accuracy: 52.0
# epoch:4 	 batch: 4 	 loss: 	 2.9206273906842624	accuracy: 42.0
# epoch:4 	 batch: 5 	 loss: 	 2.9307626167528498	accuracy: 36.0
# epoch:4 	 batch: 6 	 loss: 	 2.9611940982121494	accuracy: 40.0
# epoch:4 	 batch: 7 	 loss: 	 2.9643608314540892	accuracy: 31.0
# epoch:4 	 batch: 8 	 loss: 	 2.945833453288569	accuracy: 37.0
# epoch:4 	 batch: 9 	 loss: 	 2.933432154298777	accuracy: 28.999999999999996
# epoch:4 	 batch: 10 	 loss: 	 2.909125207045896	accuracy: 41.0
# epoch:5 	 batch: 1 	 loss: 	 2.9756350803505596	accuracy: 21.0
# epoch:5 	 batch: 2 	 loss: 	 3.0051585716895755	accuracy: 39.0
# epoch:5 	 batch: 3 	 loss: 	 2.770496661386779	accuracy: 51.0
# epoch:5 	 batch: 4 	 loss: 	 2.8143431889681882	accuracy: 43.0
# epoch:5 	 batch: 5 	 loss: 	 2.8434275645146156	accuracy: 32.0
# epoch:5 	 batch: 6 	 loss: 	 2.866584418030402	accuracy: 41.0
# epoch:5 	 batch: 7 	 loss: 	 2.868695462332972	accuracy: 34.0
# epoch:5 	 batch: 8 	 loss: 	 2.8372451700877326	accuracy: 34.0
# epoch:5 	 batch: 9 	 loss: 	 2.8444389076105243	accuracy: 31.0
# epoch:5 	 batch: 10 	 loss: 	 2.8258461793294436	accuracy: 42.0
# epoch:6 	 batch: 1 	 loss: 	 2.9141402521257804	accuracy: 24.0
# epoch:6 	 batch: 2 	 loss: 	 2.982352734092599	accuracy: 39.0
# epoch:6 	 batch: 3 	 loss: 	 2.661673004799691	accuracy: 54.0
# epoch:6 	 batch: 4 	 loss: 	 2.72517993061402	accuracy: 45.0
# epoch:6 	 batch: 5 	 loss: 	 2.771624988715712	accuracy: 31.0
# epoch:6 	 batch: 6 	 loss: 	 2.7916644271144366	accuracy: 40.0
# epoch:6 	 batch: 7 	 loss: 	 2.7848560528420934	accuracy: 36.0
# epoch:6 	 batch: 8 	 loss: 	 2.782755785256912	accuracy: 35.0
# epoch:6 	 batch: 9 	 loss: 	 2.818183761988085	accuracy: 25.0
# epoch:6 	 batch: 10 	 loss: 	 2.8103657413935004	accuracy: 37.0
# epoch:7 	 batch: 1 	 loss: 	 2.875518292035809	accuracy: 28.000000000000004
# epoch:7 	 batch: 2 	 loss: 	 2.980599758361218	accuracy: 37.0
# epoch:7 	 batch: 3 	 loss: 	 2.560114349645762	accuracy: 56.99999999999999
# epoch:7 	 batch: 4 	 loss: 	 2.6103371487825404	accuracy: 45.0
# epoch:7 	 batch: 5 	 loss: 	 2.684762447790117	accuracy: 28.999999999999996
# epoch:7 	 batch: 6 	 loss: 	 2.7221968006915667	accuracy: 44.0
# epoch:7 	 batch: 7 	 loss: 	 2.710229134061702	accuracy: 38.0
# epoch:7 	 batch: 8 	 loss: 	 2.7212890733461923	accuracy: 35.0
# epoch:7 	 batch: 9 	 loss: 	 2.75627745777126	accuracy: 26.0
# epoch:7 	 batch: 10 	 loss: 	 2.7632823778466604	accuracy: 34.0
# epoch:8 	 batch: 1 	 loss: 	 2.775477431807366	accuracy: 32.0
# epoch:8 	 batch: 2 	 loss: 	 2.8929477187708614	accuracy: 40.0
# epoch:8 	 batch: 3 	 loss: 	 2.460740384527261	accuracy: 61.0
# epoch:8 	 batch: 4 	 loss: 	 2.5252760970138843	accuracy: 47.0
# epoch:8 	 batch: 5 	 loss: 	 2.6131746902806965	accuracy: 32.0
# epoch:8 	 batch: 6 	 loss: 	 2.6588391925461554	accuracy: 46.0
# epoch:8 	 batch: 7 	 loss: 	 2.6256527545741335	accuracy: 38.0
# epoch:8 	 batch: 8 	 loss: 	 2.597166549085437	accuracy: 43.0
# epoch:8 	 batch: 9 	 loss: 	 2.6516706957432556	accuracy: 30.0
# epoch:8 	 batch: 10 	 loss: 	 2.6585798187675973	accuracy: 46.0
# epoch:9 	 batch: 1 	 loss: 	 2.678377595299221	accuracy: 39.0
# epoch:9 	 batch: 2 	 loss: 	 2.8188592965772856	accuracy: 41.0
# epoch:9 	 batch: 3 	 loss: 	 2.3908739249572593	accuracy: 56.00000000000001
# epoch:9 	 batch: 4 	 loss: 	 2.4949882929063203	accuracy: 48.0
# epoch:9 	 batch: 5 	 loss: 	 2.563136951698656	accuracy: 32.0
# epoch:9 	 batch: 6 	 loss: 	 2.628861445686587	accuracy: 45.0
# epoch:9 	 batch: 7 	 loss: 	 2.6451139013231058	accuracy: 41.0
# epoch:9 	 batch: 8 	 loss: 	 2.7345310149670263	accuracy: 32.0
# epoch:9 	 batch: 9 	 loss: 	 2.650259572311619	accuracy: 27.0
# epoch:9 	 batch: 10 	 loss: 	 2.6008689489046866	accuracy: 47.0
# epoch:10 	 batch: 1 	 loss: 	 2.5468770046002636	accuracy: 40.0
# epoch:10 	 batch: 2 	 loss: 	 2.6575931312612466	accuracy: 45.0
# epoch:10 	 batch: 3 	 loss: 	 2.299873238430738	accuracy: 59.0
# epoch:10 	 batch: 4 	 loss: 	 2.3666825800327143	accuracy: 55.00000000000001
# epoch:10 	 batch: 5 	 loss: 	 2.5254347994870083	accuracy: 40.0
# epoch:10 	 batch: 6 	 loss: 	 2.5866417630329828	accuracy: 44.0
# epoch:10 	 batch: 7 	 loss: 	 2.5243575638275497	accuracy: 42.0
# epoch:10 	 batch: 8 	 loss: 	 2.43806973276591	accuracy: 44.0
# epoch:10 	 batch: 9 	 loss: 	 2.50929195089713	accuracy: 44.0
# epoch:10 	 batch: 10 	 loss: 	 2.4485261854911853	accuracy: 46.0
# epoch:11 	 batch: 1 	 loss: 	 2.4909760790177136	accuracy: 46.0
# epoch:11 	 batch: 2 	 loss: 	 2.645712691309865	accuracy: 45.0
# epoch:11 	 batch: 3 	 loss: 	 2.297346767946767	accuracy: 48.0
# epoch:11 	 batch: 4 	 loss: 	 2.3735615135407473	accuracy: 49.0
# epoch:11 	 batch: 5 	 loss: 	 2.4533464809705343	accuracy: 38.0
# epoch:11 	 batch: 6 	 loss: 	 2.4952515456162847	accuracy: 49.0
# epoch:11 	 batch: 7 	 loss: 	 2.4749265734208663	accuracy: 43.0
# epoch:11 	 batch: 8 	 loss: 	 2.498389732265631	accuracy: 38.0
# epoch:11 	 batch: 9 	 loss: 	 2.594544544974541	accuracy: 32.0
# epoch:11 	 batch: 10 	 loss: 	 2.6005872381976496	accuracy: 39.0
# epoch:12 	 batch: 1 	 loss: 	 2.4755851198290446	accuracy: 42.0
# epoch:12 	 batch: 2 	 loss: 	 2.618116231648053	accuracy: 44.0
# epoch:12 	 batch: 3 	 loss: 	 2.1424780773772256	accuracy: 56.00000000000001
# epoch:12 	 batch: 4 	 loss: 	 2.20225273005165	accuracy: 62.0
# epoch:12 	 batch: 5 	 loss: 	 2.338901768189216	accuracy: 42.0
# epoch:12 	 batch: 6 	 loss: 	 2.477400141710595	accuracy: 49.0
# epoch:12 	 batch: 7 	 loss: 	 2.52434160311617	accuracy: 41.0
# epoch:12 	 batch: 8 	 loss: 	 2.545796236023153	accuracy: 33.0
# epoch:12 	 batch: 9 	 loss: 	 2.531804318543251	accuracy: 34.0
# epoch:12 	 batch: 10 	 loss: 	 2.5223165470011724	accuracy: 49.0
# epoch:13 	 batch: 1 	 loss: 	 2.4654331861278553	accuracy: 44.0
# epoch:13 	 batch: 2 	 loss: 	 2.663127029813716	accuracy: 44.0
# epoch:13 	 batch: 3 	 loss: 	 2.060761573400203	accuracy: 59.0
# epoch:13 	 batch: 4 	 loss: 	 2.093658816009369	accuracy: 63.0
# epoch:13 	 batch: 5 	 loss: 	 2.234353747504181	accuracy: 47.0
# epoch:13 	 batch: 6 	 loss: 	 2.3888713358973606	accuracy: 47.0
# epoch:13 	 batch: 7 	 loss: 	 2.443431954816664	accuracy: 43.0
# epoch:13 	 batch: 8 	 loss: 	 2.3992586874130635	accuracy: 39.0
# epoch:13 	 batch: 9 	 loss: 	 2.50444188594414	accuracy: 36.0
# epoch:13 	 batch: 10 	 loss: 	 2.4175858067469242	accuracy: 46.0
# epoch:14 	 batch: 1 	 loss: 	 2.3469263172952357	accuracy: 49.0
# epoch:14 	 batch: 2 	 loss: 	 2.528318647272017	accuracy: 40.0
# epoch:14 	 batch: 3 	 loss: 	 2.3618771588754743	accuracy: 43.0
# epoch:14 	 batch: 4 	 loss: 	 2.448850218368653	accuracy: 39.0
# epoch:14 	 batch: 5 	 loss: 	 2.481623060763732	accuracy: 44.0
# epoch:14 	 batch: 6 	 loss: 	 2.4013456581265586	accuracy: 49.0
# epoch:14 	 batch: 7 	 loss: 	 2.4352440339267902	accuracy: 47.0
# epoch:14 	 batch: 8 	 loss: 	 2.2956803817244413	accuracy: 48.0
# epoch:14 	 batch: 9 	 loss: 	 2.5093435060169997	accuracy: 41.0
# epoch:14 	 batch: 10 	 loss: 	 2.3771550205131815	accuracy: 48.0
# epoch:15 	 batch: 1 	 loss: 	 2.3291878549191636	accuracy: 53.0
# epoch:15 	 batch: 2 	 loss: 	 2.500011296994262	accuracy: 43.0
# epoch:15 	 batch: 3 	 loss: 	 2.011733644415608	accuracy: 64.0
# epoch:15 	 batch: 4 	 loss: 	 2.0734634366618394	accuracy: 59.0
# epoch:15 	 batch: 5 	 loss: 	 2.205121188315658	accuracy: 51.0
# epoch:15 	 batch: 6 	 loss: 	 2.309780336287349	accuracy: 50.0
# epoch:15 	 batch: 7 	 loss: 	 2.3163220395316917	accuracy: 47.0
# epoch:15 	 batch: 8 	 loss: 	 2.2987825740638583	accuracy: 46.0
# epoch:15 	 batch: 9 	 loss: 	 2.450737782197962	accuracy: 37.0
# epoch:15 	 batch: 10 	 loss: 	 2.3969568941323574	accuracy: 47.0
# epoch:16 	 batch: 1 	 loss: 	 2.4265940341444807	accuracy: 46.0
# epoch:16 	 batch: 2 	 loss: 	 2.724563471416035	accuracy: 47.0
# epoch:16 	 batch: 3 	 loss: 	 2.061758580667255	accuracy: 52.0
# epoch:16 	 batch: 4 	 loss: 	 2.2564638785174798	accuracy: 54.0
# epoch:16 	 batch: 5 	 loss: 	 2.365020219964767	accuracy: 41.0
# epoch:16 	 batch: 6 	 loss: 	 2.489587904130517	accuracy: 51.0
# epoch:16 	 batch: 7 	 loss: 	 2.591859188337618	accuracy: 40.0
# epoch:16 	 batch: 8 	 loss: 	 2.3673101186571817	accuracy: 43.0
# epoch:16 	 batch: 9 	 loss: 	 2.3326040768586935	accuracy: 40.0
# epoch:16 	 batch: 10 	 loss: 	 2.267870951756843	accuracy: 51.0
# epoch:17 	 batch: 1 	 loss: 	 2.2624201129358377	accuracy: 51.0
# epoch:17 	 batch: 2 	 loss: 	 2.3499083864438517	accuracy: 54.0
# epoch:17 	 batch: 3 	 loss: 	 1.928567591487576	accuracy: 62.0
# epoch:17 	 batch: 4 	 loss: 	 1.9601474673705384	accuracy: 63.0
# epoch:17 	 batch: 5 	 loss: 	 2.0873590996799756	accuracy: 54.0
# epoch:17 	 batch: 6 	 loss: 	 2.265929368671957	accuracy: 49.0
# epoch:17 	 batch: 7 	 loss: 	 2.2979120909537984	accuracy: 47.0
# epoch:17 	 batch: 8 	 loss: 	 2.283480978414074	accuracy: 40.0
# epoch:17 	 batch: 9 	 loss: 	 2.401492318552256	accuracy: 40.0
# epoch:17 	 batch: 10 	 loss: 	 2.297902468858333	accuracy: 49.0
# epoch:18 	 batch: 1 	 loss: 	 2.3169281296236814	accuracy: 51.0
# epoch:18 	 batch: 2 	 loss: 	 2.3455829246588102	accuracy: 53.0
# epoch:18 	 batch: 3 	 loss: 	 1.8972281755979798	accuracy: 61.0
# epoch:18 	 batch: 4 	 loss: 	 1.9262293494683724	accuracy: 63.0
# epoch:18 	 batch: 5 	 loss: 	 2.036117033924522	accuracy: 59.0
# epoch:18 	 batch: 6 	 loss: 	 2.2420404615876692	accuracy: 50.0
# epoch:18 	 batch: 7 	 loss: 	 2.318497218433813	accuracy: 46.0
# epoch:18 	 batch: 8 	 loss: 	 2.288881330405269	accuracy: 44.0
# epoch:18 	 batch: 9 	 loss: 	 2.370907856518434	accuracy: 40.0
# epoch:18 	 batch: 10 	 loss: 	 2.2446338349753234	accuracy: 48.0
# epoch:19 	 batch: 1 	 loss: 	 2.279167725343565	accuracy: 50.0
# epoch:19 	 batch: 2 	 loss: 	 2.3818848681953937	accuracy: 52.0
# epoch:19 	 batch: 3 	 loss: 	 1.834509541679572	accuracy: 68.0
# epoch:19 	 batch: 4 	 loss: 	 1.8703073004177195	accuracy: 64.0
# epoch:19 	 batch: 5 	 loss: 	 2.04270136552754	accuracy: 56.99999999999999
# epoch:19 	 batch: 6 	 loss: 	 2.260802413550662	accuracy: 53.0
# epoch:19 	 batch: 7 	 loss: 	 2.405151430431528	accuracy: 46.0
# epoch:19 	 batch: 8 	 loss: 	 2.2568171209650547	accuracy: 52.0
# epoch:19 	 batch: 9 	 loss: 	 2.2944262397938386	accuracy: 43.0
# epoch:19 	 batch: 10 	 loss: 	 2.5153347312271546	accuracy: 47.0
# epoch:20 	 batch: 1 	 loss: 	 2.7439219329888913	accuracy: 45.0
# epoch:20 	 batch: 2 	 loss: 	 2.67623392129941	accuracy: 46.0
# epoch:20 	 batch: 3 	 loss: 	 2.0566874804632693	accuracy: 52.0
# epoch:20 	 batch: 4 	 loss: 	 2.2730666146630574	accuracy: 51.0
# epoch:20 	 batch: 5 	 loss: 	 2.084548865369708	accuracy: 53.0
# epoch:20 	 batch: 6 	 loss: 	 2.174040164825271	accuracy: 56.99999999999999
# epoch:20 	 batch: 7 	 loss: 	 2.2963785034925985	accuracy: 50.0
# epoch:20 	 batch: 8 	 loss: 	 2.0815359748799676	accuracy: 55.00000000000001
# epoch:20 	 batch: 9 	 loss: 	 2.137688064137782	accuracy: 47.0
# epoch:20 	 batch: 10 	 loss: 	 2.1771835843168517	accuracy: 56.99999999999999
# epoch:21 	 batch: 1 	 loss: 	 2.090474546319491	accuracy: 60.0
# epoch:21 	 batch: 2 	 loss: 	 2.199476161933088	accuracy: 52.0
# epoch:21 	 batch: 3 	 loss: 	 1.7348537566623912	accuracy: 67.0
# epoch:21 	 batch: 4 	 loss: 	 1.7902775243314095	accuracy: 70.0
# epoch:21 	 batch: 5 	 loss: 	 1.9142122222112568	accuracy: 64.0
# epoch:21 	 batch: 6 	 loss: 	 2.165953728923556	accuracy: 49.0
# epoch:21 	 batch: 7 	 loss: 	 2.293052635713761	accuracy: 47.0
# epoch:21 	 batch: 8 	 loss: 	 2.294380809971044	accuracy: 42.0
# epoch:21 	 batch: 9 	 loss: 	 2.4248907350812057	accuracy: 41.0
# epoch:21 	 batch: 10 	 loss: 	 2.3993952355144192	accuracy: 46.0
# epoch:22 	 batch: 1 	 loss: 	 2.45418236573993	accuracy: 50.0
# epoch:22 	 batch: 2 	 loss: 	 2.3507516204251653	accuracy: 53.0
# epoch:22 	 batch: 3 	 loss: 	 1.9535366903108622	accuracy: 57.99999999999999
# epoch:22 	 batch: 4 	 loss: 	 1.8919642252038467	accuracy: 61.0
# epoch:22 	 batch: 5 	 loss: 	 1.9237002683816533	accuracy: 57.99999999999999
# epoch:22 	 batch: 6 	 loss: 	 2.170997962708698	accuracy: 50.0
# epoch:22 	 batch: 7 	 loss: 	 2.2382839131690684	accuracy: 48.0
# epoch:22 	 batch: 8 	 loss: 	 2.124076152151562	accuracy: 47.0
# epoch:22 	 batch: 9 	 loss: 	 2.1907912955892197	accuracy: 45.0
# epoch:22 	 batch: 10 	 loss: 	 2.15732881198531	accuracy: 56.00000000000001
# epoch:23 	 batch: 1 	 loss: 	 2.169138595523638	accuracy: 56.99999999999999
# epoch:23 	 batch: 2 	 loss: 	 2.1662401008167005	accuracy: 52.0
# epoch:23 	 batch: 3 	 loss: 	 1.7600254106417736	accuracy: 70.0
# epoch:23 	 batch: 4 	 loss: 	 1.8032933376371079	accuracy: 63.0
# epoch:23 	 batch: 5 	 loss: 	 1.8904464116231117	accuracy: 60.0
# epoch:23 	 batch: 6 	 loss: 	 2.18892003902955	accuracy: 49.0
# epoch:23 	 batch: 7 	 loss: 	 2.2374731566771886	accuracy: 50.0
# epoch:23 	 batch: 8 	 loss: 	 2.177360528979892	accuracy: 47.0
# epoch:23 	 batch: 9 	 loss: 	 2.218228830425239	accuracy: 47.0
# epoch:23 	 batch: 10 	 loss: 	 2.12241640305238	accuracy: 56.00000000000001
# epoch:24 	 batch: 1 	 loss: 	 2.1156583048293847	accuracy: 56.00000000000001
# epoch:24 	 batch: 2 	 loss: 	 2.084381156242186	accuracy: 55.00000000000001
# epoch:24 	 batch: 3 	 loss: 	 1.7109314728273843	accuracy: 71.0
# epoch:24 	 batch: 4 	 loss: 	 1.6964860052057886	accuracy: 68.0
# epoch:24 	 batch: 5 	 loss: 	 1.7981548886847971	accuracy: 64.0
# epoch:24 	 batch: 6 	 loss: 	 2.046437665337974	accuracy: 57.99999999999999
# epoch:24 	 batch: 7 	 loss: 	 2.164784701671256	accuracy: 52.0
# epoch:24 	 batch: 8 	 loss: 	 2.0923323365867112	accuracy: 49.0
# epoch:24 	 batch: 9 	 loss: 	 2.135207956595845	accuracy: 46.0
# epoch:24 	 batch: 10 	 loss: 	 2.07793466957115	accuracy: 56.99999999999999
# epoch:25 	 batch: 1 	 loss: 	 2.0747915657957994	accuracy: 59.0
# epoch:25 	 batch: 2 	 loss: 	 2.103531080700746	accuracy: 54.0
# epoch:25 	 batch: 3 	 loss: 	 1.7493135992127313	accuracy: 64.0
# epoch:25 	 batch: 4 	 loss: 	 1.8333400268865216	accuracy: 64.0
# epoch:25 	 batch: 5 	 loss: 	 1.9852724450223727	accuracy: 56.00000000000001
# epoch:25 	 batch: 6 	 loss: 	 2.1141952087275944	accuracy: 62.0
# epoch:25 	 batch: 7 	 loss: 	 2.229158010891956	accuracy: 52.0
# epoch:25 	 batch: 8 	 loss: 	 1.9897059805171962	accuracy: 56.99999999999999
# epoch:25 	 batch: 9 	 loss: 	 2.0675763968915875	accuracy: 51.0
# epoch:25 	 batch: 10 	 loss: 	 2.2076330621374365	accuracy: 53.0
# epoch:26 	 batch: 1 	 loss: 	 2.1776982199287147	accuracy: 57.99999999999999
# epoch:26 	 batch: 2 	 loss: 	 2.2674741071310267	accuracy: 47.0
# epoch:26 	 batch: 3 	 loss: 	 1.8605495639898186	accuracy: 55.00000000000001
# epoch:26 	 batch: 4 	 loss: 	 1.9053414903183634	accuracy: 62.0
# epoch:26 	 batch: 5 	 loss: 	 1.8737352521537307	accuracy: 57.99999999999999
# epoch:26 	 batch: 6 	 loss: 	 2.017382223862537	accuracy: 62.0
# epoch:26 	 batch: 7 	 loss: 	 2.1572874832887514	accuracy: 56.00000000000001
# epoch:26 	 batch: 8 	 loss: 	 1.9157931355711775	accuracy: 59.0
# epoch:26 	 batch: 9 	 loss: 	 2.014835087544583	accuracy: 47.0
# epoch:26 	 batch: 10 	 loss: 	 2.0794759504485976	accuracy: 51.0
# epoch:27 	 batch: 1 	 loss: 	 1.9737193962196653	accuracy: 57.99999999999999
# epoch:27 	 batch: 2 	 loss: 	 2.0467052592808685	accuracy: 53.0
# epoch:27 	 batch: 3 	 loss: 	 1.649180511303	accuracy: 67.0
# epoch:27 	 batch: 4 	 loss: 	 1.6728285138708774	accuracy: 69.0
# epoch:27 	 batch: 5 	 loss: 	 1.7440845866817631	accuracy: 65.0
# epoch:27 	 batch: 6 	 loss: 	 1.96708551049437	accuracy: 62.0
# epoch:27 	 batch: 7 	 loss: 	 2.1129555736023513	accuracy: 55.00000000000001
# epoch:27 	 batch: 8 	 loss: 	 1.9195489934980394	accuracy: 56.99999999999999
# epoch:27 	 batch: 9 	 loss: 	 2.015324455014634	accuracy: 48.0
# epoch:27 	 batch: 10 	 loss: 	 2.0777616331791684	accuracy: 60.0
# epoch:28 	 batch: 1 	 loss: 	 1.995447438004818	accuracy: 60.0
# epoch:28 	 batch: 2 	 loss: 	 1.9451205263906775	accuracy: 60.0
# epoch:28 	 batch: 3 	 loss: 	 1.6391147238411405	accuracy: 71.0
# epoch:28 	 batch: 4 	 loss: 	 1.6969640364640985	accuracy: 68.0
# epoch:28 	 batch: 5 	 loss: 	 1.814354473781467	accuracy: 63.0
# epoch:28 	 batch: 6 	 loss: 	 2.1573637886155437	accuracy: 53.0
# epoch:28 	 batch: 7 	 loss: 	 2.269888943844843	accuracy: 48.0
# epoch:28 	 batch: 8 	 loss: 	 2.294647323555218	accuracy: 45.0
# epoch:28 	 batch: 9 	 loss: 	 2.2097794962951505	accuracy: 50.0
# epoch:28 	 batch: 10 	 loss: 	 2.1564468160909844	accuracy: 52.0
# epoch:29 	 batch: 1 	 loss: 	 2.0094094675327026	accuracy: 60.0
# epoch:29 	 batch: 2 	 loss: 	 1.8998450624275443	accuracy: 62.0
# epoch:29 	 batch: 3 	 loss: 	 1.6121059984816757	accuracy: 70.0
# epoch:29 	 batch: 4 	 loss: 	 1.5985429897580314	accuracy: 69.0
# epoch:29 	 batch: 5 	 loss: 	 1.6891386110104134	accuracy: 66.0
# epoch:29 	 batch: 6 	 loss: 	 1.9487246456740102	accuracy: 59.0
# epoch:29 	 batch: 7 	 loss: 	 2.059208351232124	accuracy: 54.0
# epoch:29 	 batch: 8 	 loss: 	 1.9261120048592897	accuracy: 54.0
# epoch:29 	 batch: 9 	 loss: 	 1.99385950517777	accuracy: 50.0
# epoch:29 	 batch: 10 	 loss: 	 1.9336430679489802	accuracy: 57.99999999999999
# epoch:30 	 batch: 1 	 loss: 	 1.8282167224996722	accuracy: 63.0
# epoch:30 	 batch: 2 	 loss: 	 1.8224004097923165	accuracy: 59.0
# epoch:30 	 batch: 3 	 loss: 	 1.5140724842754434	accuracy: 72.0
# epoch:30 	 batch: 4 	 loss: 	 1.5401673901924846	accuracy: 70.0
# epoch:30 	 batch: 5 	 loss: 	 1.6119379371799207	accuracy: 68.0
# epoch:30 	 batch: 6 	 loss: 	 1.8645740179441248	accuracy: 64.0
# epoch:30 	 batch: 7 	 loss: 	 2.0050181264118483	accuracy: 57.99999999999999
# epoch:30 	 batch: 8 	 loss: 	 1.793030832935302	accuracy: 63.0
# epoch:30 	 batch: 9 	 loss: 	 1.971540985084517	accuracy: 52.0
# epoch:30 	 batch: 10 	 loss: 	 1.982260008889842	accuracy: 54.0
# The final loss is 2.0764089765870355
# The final accuracy on train set is 53.86

# %%
(Xtr, Ytr), (Xte, Yte) = Mnist.load_data()

# 4. Сургалтын өгөгдлийг БҮГДИЙГ ашиглана (60000 зураг)
X_training = Xtr.astype(np.float32) / 255.0   # (60000,28,28)
Y_training = Ytr                              # (60000,)

al = 0.3
stopper = 85.0

complete_NN = ConvNet([
    padding(),
    ConvLayer(),
    Pooling(),
    relu(),

    padding(),
    ConvLayer(),
    Pooling(),
    relu(),

    ConvLayer(),
    relu(),

    reshaping(),
    Linear_Layer(5*5, 24, alpha=al),
    relu(),
    Linear_Layer(24, 10, alpha=al),
    softmax()
])

CE = cross_entropy()
acc = accuracy()

epochs = 1          # бүх өгөгдөл дээр ажиллах тул эхлээд 1 epoch-оор туршаарай
batch_size = 100    # хүсвэл 128/256 болгож өөрчилж болно
n = X_training.shape[0]
broke = 0

for epoch in range(epochs):
    # epoch бүр shuffle
    perm = np.random.permutation(n)
    X_training = X_training[perm]
    Y_training = Y_training[perm]

    for b, start in enumerate(range(0, n, batch_size), start=1):
        end = min(start + batch_size, n)

        out = complete_NN.forward_pass(X_training[start:end])
        loss = CE.loss(out, Y_training[start:end])
        accur = acc.value(out, Y_training[start:end]) * 100

        print(f"epoch:{epoch+1}\t batch:{b}\t loss:\t {loss}\taccuracy: {accur}")

        if accur >= stopper:
            broke = 1
            break

        complete_NN.backprop(Y_training[start:end])
        complete_NN.applying_sgd()

    if broke == 1:
        break

# (сонголттой) train set дээрх эцсийн үзүүлэлтийг жижиг subset-ээр хурдан шалгаж болно
out = complete_NN.forward_pass(X_training[:1000])
print("The final loss is {}".format(CE.loss(out, Y_training[:1000])))
print("The final accuracy on train subset is {}".format(acc.value(out, Y_training[:1000]) * 100))

# Xtest = Xte.astype(np.float32) / 255.0
# out_1 = complete_NN.forward_pass(Xtest[:1000])
# print("The accuracy on test subset is {}".format(acc.value(out_1, Yte[:1000]) * 100))
# Out:
# epoch:1	 batch:1	 loss:	 8.288060377406593	accuracy: 12.0
# epoch:1	 batch:2	 loss:	 10.234723256946602	accuracy: 18.0
# epoch:1	 batch:3	 loss:	 15.870419607822774	accuracy: 4.0
# epoch:1	 batch:4	 loss:	 10.351395695931046	accuracy: 6.0
# epoch:1	 batch:5	 loss:	 8.187020569923588	accuracy: 11.0
# epoch:1	 batch:6	 loss:	 3.2919188621132607	accuracy: 6.0
# epoch:1	 batch:7	 loss:	 3.268674441550719	accuracy: 7.000000000000001
# epoch:1	 batch:8	 loss:	 3.2883711828313915	accuracy: 11.0
# epoch:1	 batch:9	 loss:	 3.275045284043531	accuracy: 9.0
# epoch:1	 batch:10	 loss:	 3.2488770895404304	accuracy: 11.0
# epoch:1	 batch:11	 loss:	 3.2968755239907352	accuracy: 11.0
# epoch:1	 batch:12	 loss:	 3.23260503880913	accuracy: 17.0
# epoch:1	 batch:13	 loss:	 3.2824387781209925	accuracy: 8.0
# epoch:1	 batch:14	 loss:	 3.2184518532408357	accuracy: 17.0
# epoch:1	 batch:15	 loss:	 3.270659030042101	accuracy: 10.0
# epoch:1	 batch:16	 loss:	 3.290454769272503	accuracy: 10.0
# epoch:1	 batch:17	 loss:	 3.254327019347377	accuracy: 9.0
# epoch:1	 batch:18	 loss:	 3.279832120048423	accuracy: 7.000000000000001
# epoch:1	 batch:19	 loss:	 3.2603030891021696	accuracy: 8.0
# epoch:1	 batch:20	 loss:	 3.2481755825403607	accuracy: 13.0
# epoch:1	 batch:21	 loss:	 3.264291421569654	accuracy: 9.0
# epoch:1	 batch:22	 loss:	 3.261767497639822	accuracy: 13.0
# epoch:1	 batch:23	 loss:	 3.290125087571995	accuracy: 6.0
# epoch:1	 batch:24	 loss:	 3.2642050518923895	accuracy: 8.0
# epoch:1	 batch:25	 loss:	 3.2707523650624757	accuracy: 7.000000000000001
# epoch:1	 batch:26	 loss:	 3.2393824115566328	accuracy: 17.0
# epoch:1	 batch:27	 loss:	 3.2480736821813014	accuracy: 17.0
# epoch:1	 batch:28	 loss:	 3.229637514155148	accuracy: 11.0
# epoch:1	 batch:29	 loss:	 3.206261852628801	accuracy: 17.0
# epoch:1	 batch:30	 loss:	 3.247073235904079	accuracy: 7.000000000000001
# epoch:1	 batch:31	 loss:	 3.2261146297641607	accuracy: 15.0
# epoch:1	 batch:32	 loss:	 3.2352903720740853	accuracy: 13.0
# epoch:1	 batch:33	 loss:	 3.2162536415560554	accuracy: 15.0
# epoch:1	 batch:34	 loss:	 3.2024981319435906	accuracy: 12.0
# epoch:1	 batch:35	 loss:	 3.1773996056562424	accuracy: 14.000000000000002
# epoch:1	 batch:36	 loss:	 3.2340122846762323	accuracy: 14.000000000000002
# epoch:1	 batch:37	 loss:	 3.1968954178184648	accuracy: 12.0
# epoch:1	 batch:38	 loss:	 3.026458980102949	accuracy: 18.0
# epoch:1	 batch:39	 loss:	 3.367796684797912	accuracy: 12.0
# epoch:1	 batch:40	 loss:	 3.221124122653281	accuracy: 11.0
# epoch:1	 batch:41	 loss:	 3.1470761753942527	accuracy: 16.0
# epoch:1	 batch:42	 loss:	 3.444422430400713	accuracy: 8.0
# epoch:1	 batch:43	 loss:	 3.2658049676909955	accuracy: 12.0
# epoch:1	 batch:44	 loss:	 3.2639037626812732	accuracy: 8.0
# epoch:1	 batch:45	 loss:	 3.2396708731385164	accuracy: 11.0
# epoch:1	 batch:46	 loss:	 3.2461598980892954	accuracy: 11.0
# epoch:1	 batch:47	 loss:	 3.2536469125386502	accuracy: 8.0
# epoch:1	 batch:48	 loss:	 3.260229575100932	accuracy: 5.0
# epoch:1	 batch:49	 loss:	 3.2504669718126102	accuracy: 13.0
# epoch:1	 batch:50	 loss:	 3.257005206220388	accuracy: 8.0
# epoch:1	 batch:51	 loss:	 3.2543332168274755	accuracy: 10.0
# epoch:1	 batch:52	 loss:	 3.264554355719143	accuracy: 10.0
# epoch:1	 batch:53	 loss:	 3.265942999030135	accuracy: 7.000000000000001
# epoch:1	 batch:54	 loss:	 3.252082756009926	accuracy: 14.000000000000002
# epoch:1	 batch:55	 loss:	 3.2573428316854605	accuracy: 10.0
# epoch:1	 batch:56	 loss:	 3.248206676768041	accuracy: 14.000000000000002
# epoch:1	 batch:57	 loss:	 3.2570811802398554	accuracy: 5.0
# epoch:1	 batch:58	 loss:	 3.2570299810834813	accuracy: 8.0
# epoch:1	 batch:59	 loss:	 3.2515761976821556	accuracy: 12.0
# epoch:1	 batch:60	 loss:	 3.2451126907962764	accuracy: 13.0
# epoch:1	 batch:61	 loss:	 3.252135778254945	accuracy: 10.0
# epoch:1	 batch:62	 loss:	 3.255826029708627	accuracy: 11.0
# epoch:1	 batch:63	 loss:	 3.247068009652951	accuracy: 16.0
# epoch:1	 batch:64	 loss:	 3.247921083940081	accuracy: 14.000000000000002
# epoch:1	 batch:65	 loss:	 3.253242218448719	accuracy: 13.0
# epoch:1	 batch:66	 loss:	 3.249476021648253	accuracy: 12.0
# epoch:1	 batch:67	 loss:	 3.2511119574280696	accuracy: 12.0
# epoch:1	 batch:68	 loss:	 3.257881061643404	accuracy: 8.0
# epoch:1	 batch:69	 loss:	 3.256362274143837	accuracy: 7.000000000000001
# epoch:1	 batch:70	 loss:	 3.2550350542410063	accuracy: 10.0
# epoch:1	 batch:71	 loss:	 3.2428564868286327	accuracy: 17.0
# epoch:1	 batch:72	 loss:	 3.2485641715040856	accuracy: 11.0
# epoch:1	 batch:73	 loss:	 3.2544611099524423	accuracy: 7.000000000000001
# epoch:1	 batch:74	 loss:	 3.2499998233419625	accuracy: 9.0
# epoch:1	 batch:75	 loss:	 3.252666079298152	accuracy: 12.0
# epoch:1	 batch:76	 loss:	 3.244235277227729	accuracy: 8.0
# epoch:1	 batch:77	 loss:	 3.25413610387618	accuracy: 10.0
# epoch:1	 batch:78	 loss:	 3.2483516117908344	accuracy: 12.0

# %% [markdown]
# # Даалгавар
#
# 3. Загварын суралцаж буй параметрүүдийн тоог гаргах
# 4. Сургалтын өгөгдлийг бүгдийг ашиглан сургалт хийх
# 5. Илүү гүн загварт сургалт хийх
# 6. Үр дүнг илүү сайн гаргах талаарх дүгнэлт хийх
